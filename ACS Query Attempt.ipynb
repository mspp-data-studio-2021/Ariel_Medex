# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import matplotlib as mplib
import matplotlib.pyplot as plt
import seaborn as sns
from autocensus import Query
# Out:
# /Users/Ariel/Desktop/NYU/Summer 2021/Policy and Data Studio/Repos/Ariel_Medex/env/lib/python3.9/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
def generate_plots(year):
    # Configure query
    query = Query(
    estimate=1,
    years=year,
    variables=['S1901_C02_001E', 'S2201_C01_001E', 'S2201_C03_034E', 'S2704_C01_028E', 'B02003_002E', 'S2701_C03_051E', 'S2704_C01_014E', 'S2704_C01_015E', 'S0101_C01_001E' ],
    for_geo=['county:005','county:061', 'county:081', 'county:047', 'county:085'],
    in_geo=['state:36'],
    # Optional arg to add geometry: 'points', 'polygons', or None (default)
    geometry='points',
    # Fill in the following with your actual Census API key
    census_api_key='7135cc5c273bb1c460ac4b569e5e1380dcd5b870'
    )
    
# Run query and collect output in dataframe
dataframe = query.run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c8e8a5d9b1c0> in <module>
#      14
#      15 # Run query and collect output in dataframe
# ---> 16 dataframe = query.run()
#
# NameError: name 'query' is not defined

# %%
for year in range(2012,2020):
    generate_plots(year)

# %%
dataframe.head()
# Out:
#                         name          geo_id geo_type  year       date  \
# 0     Bronx County, New York  0500000US36005   county  2019 2019-12-31
# 1     Kings County, New York  0500000US36047   county  2019 2019-12-31
# 2  New York County, New York  0500000US36061   county  2019 2019-12-31
# 3    Queens County, New York  0500000US36081   county  2019 2019-12-31
# 4  Richmond County, New York  0500000US36085   county  2019 2019-12-31
#
#   variable_code                             variable_label variable_concept  \
# 0   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
# 1   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
# 2   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
# 3   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
# 4   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
#
#   annotation  value                    geometry
# ...

# %%
dataframe.groupby('variable_code').describe()
# Out:
#                year                                                       \
#               count    mean  std     min     25%     50%     75%     max
# variable_code
# B02003_002E     5.0  2019.0  0.0  2019.0  2019.0  2019.0  2019.0  2019.0
#
#               value
#               count mean std min 25% 50% 75% max
# variable_code
# B02003_002E     0.0  NaN NaN NaN NaN NaN NaN NaN

# %%
dataframe.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-cf19503c6346> in <module>
# ----> 1 dataframe.count()
#
# NameError: name 'dataframe' is not defined

# %%
dataframe.head()
# Out:
#                         name          geo_id geo_type  year       date  \
# 0     Bronx County, New York  0500000US36005   county  2019 2019-12-31
# 1     Kings County, New York  0500000US36047   county  2019 2019-12-31
# 2  New York County, New York  0500000US36061   county  2019 2019-12-31
# 3    Queens County, New York  0500000US36081   county  2019 2019-12-31
# 4  Richmond County, New York  0500000US36085   county  2019 2019-12-31
#
#   variable_code                             variable_label variable_concept  \
# 0   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
# 1   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
# 2   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
# 3   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
# 4   B02003_002E  Estimate!!Total:!!Population of one race:    DETAILED RACE
#
#   annotation  value                    geometry
# ...

# %%
 # Run query and collect output in dataframe
    df = query.run()
    sns.barplot(x='Selected Geographies', y='Average Income, M Yes', data=df)
    plt.ylabel('Average Income for Medicaid Recipients')
    plt.xlabel('NYC Borough')
    plt.title('Average Income of Medicaid Recipients by Borough')
    plt.savefig(f'census_plot_{year}.png')
